# %% [markdown]
# ![](https://media.giphy.com/media/Ldepo9xvqWDYI/giphy.gif)

# %% [markdown]
# You must pick data that you would like to collect for **web-scraping OR an API**- the data **MUST** come from APIs (none of this download csv stuff). The data set will be your final project. You can ammend and make changes later to data sources and variables. Get creative!
#
# Be mindful of the timeline - ambitious project can't be completed in 2 months, but a snapshot of it can be done.
#
# You must pick one variable that does not exist yet or is not obviously common. The variable should either be web-scraped or if it is from an API, it must be calculated (and not very common). For example, songs per capita is commmon - you might have to calculate it, but it doesn't count. Genre concentration by state is a variable that is acceptable. Remember only **ONE** variable has to be calculated/webscraped, but you will need a total of 3 variables.
#
# In the final project, you will be providing your code and documentation (not this assignment). I will test the code you give me to make sure it runs.
#
# For my sanity - format the proposal to be organized. Include graphs, photos, examples, etc. But, please make it look professional and clean. The easier it is to read, the easier it is for me to grade, and better outcomes will likely follow.
#
# This is a proposal, so you do not have to collect the data now.
#
# In your proposal you must include:
# 1. Identify the website/API that you will be web-scraping data from. You can also suggest a variety of websites via web crawling (for example, if you want to crawl websites of selected non-profit organizations and collect information about the board members - this is doable.) Go outside your comfort zone - if you've worked with APIs, then do webscraping.
#
# 2. Define at least 3 variables that you will be collecting via API or webscraping. You may combine these webscraped or API collected data with other sources, but MUST cite those other datasources. You can collect data completely internally.
#
# 3. If it is an open access API, get an authorization key (if neccessary), if it is not needed, also note that. Provide evidence of this with screen shot that you obtained said key or a link (and a summary in your proposal) of the documentation that says it's freely accessible.
#
# 4. If it is not an open access API, ensure that you meet the terms and conditions (there is wiggle room here - but, if you are trying to crack a google related non-open access API, that's unreasonable and not possible in this class. However, if it is a Google/Amazon/InsertBigTechComp with open access API - that is do-able!). Most websites have terms and conditions, include a link to this information and briefly (a few sentences) describe what you can or can't get access to.
#
# 5. Identify your research question - what are you going to analyze? Remember that after getting the data, you will make meaningful graphs and run regressions with it.
#
# 6. Give me a bit of background and motivation. Why are you scraping this data? Why should you research/study this question?  This should not be personal motivation, but motivated academically.

# %% [markdown]
# -------------------------------------------------------------------------------
# I want to analyze the effect of political conflicts, involving violent actions (like war) across countries, on the trending of war-themed, politically-charged, OR overall *pessimistic* films, their parents' guides across countries or even continents, if data permits, of course.
#
# **Main Equation:**
#
# Sad Film Trending = β_0 + Conflict(0,1) + Sad Releases/All Releases + Country + PG_Rating
#
# I call these war, drama, pessimistic films "sad films" only now. I might change my mind once I see the actual data points.
#
# **Sad Film Trending** -- the number of sad films in the Top 100 (calculated);
#
# **Conflict (0,1)** -- binary variable, determining whether there is a violent conflict in a country;
#
# **Sad Releases/All Releases** -- proportion of “sad” releases over total releases.
#
# **Country** -- country of observation
#
# **PG Rating** -- parents guide rating
#
# ----------------------------------------------------------------------------
#
# **Trending, PG_Rating**:
#
# Free API options:
#
# https://developer.themoviedb.org/docs/authentication-application
#
# https://tv-api.com/api
# **(Personal API key is avaliable after a free TMDB account creation)**
#
# Paid API option:
#
# For a $10/month "start" subscription, Flix Patrol offers API calls for various metrics across different continents, streaming services, and timelines.
#
# https://flixpatrol.com/api2/ **(Requires a key of "basic auth username value", available with account creation)**
#
# **Conflict:**
#
# ACLED Endpoint - covers current political violence events: https://acleddata.com/api-documentation/acled-endpoint
#
# Instructions for API access token: https://acleddata.com/api-documentation/getting-started
#
# **Releases / Premieres (Proportion of “Sad”/Total):**
#
# https://developer.themoviedb.org/reference/movie-latest-id (Free)
#
# https://flixpatrol.com/api2/endpoint-premieres/ (Paid)
#
#
# ----------------------------------------------------------------------------
#
# **Motivation.**
# Ever since I added a second major in Economics to my Film and Screen Studies background, I have sought to analyze consumer insights and integrate a social science perspective into the field of media and entertainment. I’ve often thought that devising a cool project is impossible, given the costliness of media datasets like those of Nielsen. Now, as I’ve learnt about the APIs (even the costing FlixPatrol APIs) **and** webscraping, this class has given me a chance to develop something unordinary – something that another econometrics class wouldn’t go over but would rather leverage ready-made datasets.
# At some point, I wanted to connect initial claims, as a sign of slack, with media habits within the US, but now I can also look at a global picture with consideration of an ever-relevant topic, war. Therefore, I do think that paying for FlixPatrol, allowing that larger scale, will be worth it.

# %% [markdown]
# prof k:
# don't do paid. there are lot sof movie options.
#
# one thing you can add if you have time is to analyze key words within the summary or plot of the movie to see if it leans more sad.
#
# how do you know which countries are streaming movies?  I don't see that in the database information. Usually these sites are top 100 ever - where do you get info by country?

# %% [markdown]
# **Update:**
#
# I will analyze consumer sentiment in film reviews pre- and post-9/11.
# **Research Question:** Did 9/11 impact the consumer sentiment as seen in film reviews?
#
# **Steps:**
# 1) Web-scrape reviews for each film
# 2) Count of "negative/positive" words
# 3) Analyze average consumer sentiment for each film
#
# Here's the regression with just two periods:
#
# *Film Sentiment Score = beta0 + 9/11(0,1) + Genre + Rating + Concentration of Comedy by Month*
#
# Concentration of Comedy by Month -- to examine how many lighthearted, comedic films were released in the month of review (calculated variable)
#
# In post-9/11, I should probably distinguish between the sentiment in the short-term and the sentiment in the long-term. I am thinking of conducting an ANOVA to test significant differences among the three time periods.
#
# So, for ANOVA:
#
# 4) Aggregate by months of review and different terms
# 5) Identify average consumer sentiment for a period
#
# Additionally, I could see the general sentiment and specific sentiment for these groups:
# 1) blockbuster films (superhero, fantasy, action)
# 2) horrors
# 3) politically-charged, patriotic films
#
# Maybe, after 9/11, patriotic films started receiving more positive reviews, while horrors and superhero movies -- more negative.
#
# All variables are to be web-scraped from IMDb.
#
# This is a sentiment analysis example of Geeks for Geeks that I could use:
# https://www.geeksforgeeks.org/nlp/sentiment-analysis-on-imdb-movie-reviews/
#
# This is a sentiment machine invented by someone on Kaggle:
# https://www.kaggle.com/code/lakshmi25npathi/sentiment-analysis-of-imdb-movie-reviews
